# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
leaf1=pd.read_csv('C:/Users/HP/Downloads/leaf.csv')
#leaf1.columns= ['area','perimeter','physiological_length','physiological_width','aspect_ratio','rectangularity','circularity', \
#                'mean_r','mean_g','mean_b','stddev_r','stddev_g','stddev_b', \
#                'contrast','correlation','inverse_difference_moments','entropy', \
#                'Category'
#               ]

# %%
x= leaf1.iloc[:, :-1].values  
x
# Out:
# array([[0.00000000e+00, 1.87605200e+06, 5.54400000e+03, ...,
#         9.98399840e-01, 8.71316669e-01, 7.01788557e+00],
#        [0.00000000e+00, 1.75090500e+06, 5.38800000e+03, ...,
#         9.97333115e-01, 8.69411584e-01, 6.89946773e+00],
#        [0.00000000e+00, 1.74930600e+06, 5.38600000e+03, ...,
#         9.96869442e-01, 9.10523752e-01, 6.11017524e+00],
#        ...,
#        [0.00000000e+00, 1.14968100e+06, 4.63600000e+03, ...,
#         9.97696589e-01, 9.30295839e-01, 5.58019037e+00],
#        [0.00000000e+00, 1.14968100e+06, 4.63600000e+03, ...,
#         9.97490457e-01, 9.41047543e-01, 5.28799833e+00],
#        [0.00000000e+00, 1.14968100e+06, 4.63600000e+03, ...,
#         9.96144108e-01, 9.36064173e-01, 4.88929470e+00]])

# %%
y= leaf1.iloc[:, 18].values  
y
# Out:
# array(['Alari', 'Alari', 'Alari', ..., 'White Karisalankani',
#        'White Karisalankani', 'White Karisalankani'], dtype=object)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state = 0)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
from sklearn.naive_bayes import GaussianNB
classifier = GaussianNB()
classifier.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
y_pred = classifier.predict(X_test)
print(np.concatenate((y_pred.reshape(len(y_pred),1), y_test.reshape(len(y_test),1)),1))
# Out:
# [['Arasam' 'Arasam']
#  ['Banyan' 'Paper flower']
#  ['Manathakkali' 'Sirukeerai']
#  ['Chrysanthemum' 'Chrysanthemum']
#  ['Sirukeerai' 'Banyan']
#  ['Mint leaves' 'Curry leaves']
#  ['Star Goosberry' 'Jasmine']
#  ['Lemon' 'Celosia cristata']
#  ['Guava' 'Guava']
#  ['Poovarasam' 'Poovarasam']
#  ['Kuppaimeni' 'Kuppaimeni']
#  ['Karpooravalli' 'Karpooravalli']
#  ['Manathakkali' 'Barleria Prionitis']
#  ['Kuppaimeni' 'Kuppaimeni']
#  ['Vallarai' 'Vallarai']
#  ['Punga' 'Castor']
#  ['Pomegranate' 'Lemon']
#  ['Neem' 'Neem']
#  ['Nithya kalyani' 'Nithya kalyani']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['Bitter Gourd' 'Bitter Gourd']
#  ['Castor' 'Castor']
#  ['Karpooravalli' 'Karpooravalli']
#  ['White Karisalankani' 'White Karisalankani']
#  ['Vallarai' 'Vallarai']
#  ['Tulasi' 'Mullai']
#  ['Banyan' 'Banyan']
#  ['Pomegranate' 'Bryophyllum']
#  ['Paper flower' 'Paper flower']
#  ['Fig' 'Bryophyllum']
#  ['Mango' 'Arasam']
#  ['Bitter Gourd' 'Bitter Gourd']
#  ['Palak' 'Palak']
#  ['Hibiscus' 'Celosia cristata']
#  ['Paper flower' 'Paper flower']
#  ['Bryophyllum' 'Lemon']
#  ['Poovarasam' 'Poovarasam']
#  ['Mint leaves' 'Mint leaves']
#  ['Badam' 'Badam']
#  ['Arasam' 'Guava']
#  ['Nandhiyavattai' 'Alari']
#  ['Mango' 'Arasam']
#  ['Lemon' 'Celosia cristata']
#  ['Mango' 'Arasam']
#  ['Palak' 'Palak']
#  ['Neem' 'Pomegranate']
#  ['Punga' 'Castor']
#  ['Tomato' 'Tomato']
#  ['Manathakkali' 'Manathakkali']
#  ['Pomegranate' 'Neem']
#  ['Pomegranate' 'Pomegranate']
#  ['Idly flower' 'Idly flower']
#  ['Tulasi' 'Mullai']
#  ['Bitter Gourd' 'Bitter Gourd']
#  ['Nandhiyavattai' 'Barleria Prionitis']
#  ['Kuppaimeni' 'Kuppaimeni']
#  ['Idly flower' 'Idly flower']
#  ['Palak' 'Palak']
#  ['Punga' 'Punga']
#  ['Marigold' 'Chickoo']
#  ['Star Goosberry' 'Star Goosberry']
#  ['Star Goosberry' 'Star Goosberry']
#  ['December flower' 'December flower']
#  ['Paper flower' 'Mutingia Calabura']
#  ['Nandhiyavattai' 'Barleria Prionitis']
#  ['Punga' 'Kuppaimeni']
#  ['Mint leaves' 'Mint leaves']
#  ['kanagambaram' 'Jasmine']
#  ['Nithya kalyani' 'Nithya kalyani']
#  ['Manathakkali' 'Barleria Prionitis']
#  ['Kaffir Lime' 'Chickoo']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Sirukeerai' 'Sirukeerai']
#  ['Tomato' 'Tomato']
#  ['Kaffir Lime' 'Kaffir Lime']
#  ['Paper flower' 'Manathakkali']
#  ['Pomegranate' 'Neem']
#  ['Fig' 'Fig']
#  ['Vallarai' 'Vallarai']
#  ['Punga' 'Punga']
#  ['Chrysanthemum' 'Jasmine']
#  ['Palak' 'Palak']
#  ['Lemon' 'Celosia cristata']
#  ['Star Goosberry' 'Star Goosberry']
#  ['Bryophyllum' 'Fig']
#  ['Nithya kalyani' 'Nithya kalyani']
#  ['Mango' 'Mango']
#  ['Ashoka' 'Ashoka']
#  ['Sangu Pushpam' 'Sangu Pushpam']
#  ['Nandhiyavattai' 'Nandhiyavattai']
#  ['Neem' 'Marigold']
#  ['Star Goosberry' 'Star Goosberry']
#  ['Guava' 'Guava']
#  ['Chrysanthemum' 'Chrysanthemum']
#  ['Star Goosberry' 'Star Goosberry']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['Badam' 'Celosia cristata']
#  ['Neem' 'Neem']
#  ['Tomato' 'Tomato']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Fig' 'Fig']
#  ['Sangu Pushpam' 'Sangu Pushpam']
#  ['Star Goosberry' 'Star Goosberry']
#  ['Punga' 'Castor']
#  ['Mullai' 'Mullai']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['White Karisalankani' 'White Karisalankani']
#  ['Ashoka' 'Ashoka']
#  ['Punga' 'Idly flower']
#  ['Sirukeerai' 'Paper flower']
#  ['Bryophyllum' 'Bryophyllum']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Fig' 'Hibiscus']
#  ['Neem' 'Neem']
#  ['Senbagam' 'Senbagam']
#  ['Nandhiyavattai' 'Alari']
#  ['Banyan' 'Paper flower']
#  ['Hibiscus' 'Hibiscus']
#  ['Kaffir Lime' 'Marigold']
#  ['Punga' 'Punga']
#  ['Banyan' 'Banyan']
#  ['Curry leaves' 'Curry leaves']
#  ['Pomegranate' 'Pomegranate']
#  ['Karpooravalli' 'Karpooravalli']
#  ['Arasam' 'Arasam']
#  ['Mango' 'Mango']
#  ['Tomato' 'Tomato']
#  ['Arasam' 'Arasam']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['Pomegranate' 'Kaffir Lime']
#  ['Senbagam' 'Senbagam']
#  ['Mullai' 'Tulasi']
#  ['Chickoo' 'Chickoo']
#  ['Curry leaves' 'Mint leaves']
#  ['Chickoo' 'Bryophyllum']
#  ['Hibiscus' 'Hibiscus']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Sirukeerai' 'Paper flower']
#  ['Pomegranate' 'Neem']
#  ['Sirukeerai' 'Sirukeerai']
#  ['Tulasi' 'Tulasi']
#  ['Kuppaimeni' 'Badam']
#  ['Pomegranate' 'Marigold']
#  ['Celosia cristata' 'Bryophyllum']
#  ['Pomegranate' 'Pomegranate']
#  ['Kaffir Lime' 'Kaffir Lime']
#  ['kanagambaram' 'kanagambaram']
#  ['Chickoo' 'Chickoo']
#  ['December flower' 'December flower']
#  ['Punga' 'Punga']
#  ['White Karisalankani' 'White Karisalankani']
#  ['Pomegranate' 'Pomegranate']
#  ['Bryophyllum' 'Marigold']
#  ['Vallarai' 'Vallarai']
#  ['Star Goosberry' 'Jasmine']
#  ['Alari' 'Alari']
#  ['Marigold' 'Fig']
#  ['Guava' 'Guava']
#  ['Hibiscus' 'Hibiscus']
#  ['Punga' 'Kuppaimeni']
#  ['kanagambaram' 'Jasmine']
#  ['Fig' 'Kaffir Lime']
#  ['Bitter Gourd' 'Bitter Gourd']
#  ['Lemon' 'Celosia cristata']
#  ['Paper flower' 'Mutingia Calabura']
#  ['Pomegranate' 'Fig']
#  ['Sangu Pushpam' 'Sangu Pushpam']
#  ['Sangu Pushpam' 'Sangu Pushpam']
#  ['Tomato' 'Tomato']
#  ['Pomegranate' 'Pomegranate']
#  ['Alari' 'Alari']
#  ['Kuppaimeni' 'Kuppaimeni']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['Bryophyllum' 'Chickoo']
#  ['White Karisalankani' 'White Karisalankani']
#  ['Tomato' 'Tomato']
#  ['Manathakkali' 'Sirukeerai']
#  ['Fig' 'Hibiscus']
#  ['Alari' 'Alari']
#  ['Lemon' 'Fig']
#  ['Banyan' 'Paper flower']
#  ['Mango' 'Arasam']
#  ['Palak' 'Palak']
#  ['Jasmine' 'kanagambaram']
#  ['Arasam' 'Arasam']
#  ['Nithya kalyani' 'Nithya kalyani']
#  ['Kaffir Lime' 'Kaffir Lime']
#  ['kanagambaram' 'Jasmine']
#  ['Paper flower' 'Manathakkali']
#  ['Vallarai' 'Vallarai']
#  ['December flower' 'December flower']
#  ['Tulasi' 'Tulasi']
#  ['Curry leaves' 'Curry leaves']
#  ['Nandhiyavattai' 'Nandhiyavattai']
#  ['Hibiscus' 'Hibiscus']
#  ['Sirukeerai' 'Banyan']
#  ['Tulasi' 'Mullai']
#  ['Palak' 'Palak']
#  ['Mint leaves' 'Mint leaves']
#  ['Curry leaves' 'Curry leaves']
#  ['Arasam' 'Arasam']
#  ['Bryophyllum' 'Chickoo']
#  ['Idly flower' 'Idly flower']
#  ['Alari' 'Nandhiyavattai']
#  ['Alari' 'Alari']
#  ['Nandhiyavattai' 'Alari']
#  ['kanagambaram' 'kanagambaram']
#  ['Palak' 'Palak']
#  ['Neem' 'Neem']
#  ['Bitter Gourd' 'Bitter Gourd']
#  ['Fig' 'Fig']
#  ['Bryophyllum' 'Kaffir Lime']
#  ['Idly flower' 'Idly flower']
#  ['Arasam' 'Arasam']
#  ['Senbagam' 'Senbagam']
#  ['Sangu Pushpam' 'Sangu Pushpam']
#  ['Nandhiyavattai' 'Nandhiyavattai']
#  ['Paper flower' 'Paper flower']
#  ['Senbagam' 'Senbagam']
#  ['Neem' 'Pomegranate']
#  ['Mango' 'Arasam']
#  ['Bryophyllum' 'Bryophyllum']
#  ['Tulasi' 'Mullai']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['December flower' 'December flower']
#  ['Marigold' 'Chickoo']
#  ['kanagambaram' 'kanagambaram']
#  ['Celosia cristata' 'Bryophyllum']
#  ['Sirukeerai' 'Sirukeerai']
#  ['Banyan' 'Mutingia Calabura']
#  ['Guava' 'Guava']
#  ['Neem' 'Neem']
#  ['Alari' 'Alari']
#  ['Nandhiyavattai' 'Alari']
#  ['Paper flower' 'Mutingia Calabura']
#  ['Tulasi' 'Tulasi']
#  ['Karpooravalli' 'Karpooravalli']
#  ['Punga' 'Punga']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['Karpooravalli' 'Karpooravalli']
#  ['Bryophyllum' 'Chickoo']
#  ['Sirukeerai' 'Sirukeerai']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Marigold' 'Chickoo']
#  ['Banyan' 'Banyan']
#  ['Bitter Gourd' 'Bitter Gourd']
#  ['Star Goosberry' 'Star Goosberry']
#  ['Castor' 'Castor']
#  ['Sangu Pushpam' 'Sangu Pushpam']
#  ['Banyan' 'Mutingia Calabura']
#  ['Tulasi' 'Nandhiyavattai']
#  ['Nandhiyavattai' 'Alari']
#  ['Bryophyllum' 'Lemon']
#  ['Neem' 'Neem']
#  ['Manathakkali' 'Manathakkali']
#  ['Guava' 'Guava']
#  ['Sirukeerai' 'Mutingia Calabura']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['Neem' 'Neem']
#  ['Chrysanthemum' 'Chrysanthemum']
#  ['Kaffir Lime' 'Kaffir Lime']
#  ['Tulasi' 'Tulasi']
#  ['Senbagam' 'Senbagam']
#  ['Ashoka' 'Ashoka']
#  ['Guava' 'Guava']
#  ['December flower' 'December flower']
#  ['Kuppaimeni' 'Badam']
#  ['Lemon' 'Marigold']
#  ['Guava' 'Guava']
#  ['Karpooravalli' 'Karpooravalli']
#  ['Mango' 'Arasam']
#  ['Tomato' 'Tomato']
#  ['Kuppaimeni' 'Ashoka']
#  ['Marigold' 'Fig']
#  ['Sirukeerai' 'Sirukeerai']
#  ['Tulasi' 'Nandhiyavattai']
#  ['Kuppaimeni' 'Castor']
#  ['Karpooravalli' 'Karpooravalli']
#  ['Bryophyllum' 'Fig']
#  ['Mango' 'Mango']
#  ['Bitter Gourd' 'Bitter Gourd']
#  ['Manathakkali' 'Barleria Prionitis']
#  ['Nandhiyavattai' 'Alari']
#  ['Palak' 'Palak']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['Mango' 'Mango']
#  ['Punga' 'Idly flower']
#  ['Bryophyllum' 'Hibiscus']
#  ['Banyan' 'Paper flower']
#  ['Kuppaimeni' 'Kuppaimeni']
#  ['Sirukeerai' 'Sirukeerai']
#  ['Punga' 'Idly flower']
#  ['Nithya kalyani' 'Nithya kalyani']
#  ['kanagambaram' 'Chrysanthemum']
#  ['White Karisalankani' 'White Karisalankani']
#  ['Pomegranate' 'Pomegranate']
#  ['Tulasi' 'Tulasi']
#  ['December flower' 'December flower']
#  ['Mint leaves' 'Mint leaves']
#  ['Fig' 'Chickoo']
#  ['Lemon' 'Fig']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Chrysanthemum' 'Jasmine']
#  ['White Karisalankani' 'White Karisalankani']
#  ['Guava' 'Guava']
#  ['Kuppaimeni' 'Kuppaimeni']
#  ['Hibiscus' 'Hibiscus']
#  ['Fig' 'Fig']
#  ['Manathakkali' 'Mutingia Calabura']
#  ['Idly flower' 'Idly flower']
#  ['Fig' 'Fig']
#  ['Idly flower' 'Idly flower']
#  ['Karpooravalli' 'Karpooravalli']
#  ['Karpooravalli' 'Karpooravalli']
#  ['Tulasi' 'Tulasi']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['Guava' 'Guava']
#  ['Guava' 'Guava']
#  ['Guava' 'Guava']
#  ['Tharai Pasalai' 'Tharai Pasalai']
#  ['kanagambaram' 'Jasmine']
#  ['Chickoo' 'Marigold']
#  ['Nithya kalyani' 'Nithya kalyani']
#  ['December flower' 'December flower']
#  ['Tulasi' 'Tulasi']
#  ['Tulasi' 'Tulasi']
#  ['Kuppaimeni' 'Castor']
#  ['Sangu Pushpam' 'Sangu Pushpam']
#  ['Tomato' 'Tomato']
#  ['Vallarai' 'Vallarai']
#  ['Tomato' 'Tomato']
#  ['Punga' 'Punga']
#  ['kanagambaram' 'kanagambaram']
#  ['Star Goosberry' 'Star Goosberry']
#  ['Chrysanthemum' 'Jasmine']
#  ['Sangu Pushpam' 'Sangu Pushpam']
#  ['Sirukeerai' 'Manathakkali']
#  ['Neem' 'Marigold']
#  ['Guava' 'Guava']
#  ['December flower' 'December flower']
#  ['Pomegranate' 'Pomegranate']
#  ['Chrysanthemum' 'Jasmine']
#  ['White Karisalankani' 'White Karisalankani']
#  ['Nattu Ponnanganni' 'Nattu Ponnanganni']
#  ['Manathakkali' 'Manathakkali']
#  ['Vallarai' 'Vallarai']
#  ['Bitter Gourd' 'Bitter Gourd']
#  ['Kuppaimeni' 'Castor']
#  ['Manathakkali' 'Sirukeerai']
#  ['Punga' 'Kuppaimeni']
#  ['Tulasi' 'Tulasi']
#  ['Nithya kalyani' 'Nithya kalyani']
#  ['Mango' 'Arasam']
#  ['Neem' 'Lemon']
#  ['Kuppaimeni' 'Kuppaimeni']
#  ['Idly flower' 'Idly flower']
#  ['Mango' 'Mango']
#  ['Banyan' 'Manathakkali']]

# %%
from sklearn.metrics import confusion_matrix, accuracy_score
ac = accuracy_score(y_test,y_pred)
cm = confusion_matrix(y_test, y_pred)

# %%
ac
# Out:
# 0.65

# %%
cm
# Out:
# array([[5, 0, 0, ..., 0, 0, 0],
#        [0, 6, 0, ..., 0, 0, 0],
#        [0, 0, 3, ..., 0, 0, 0],
#        ...,
#        [0, 0, 0, ..., 7, 0, 0],
#        [0, 0, 0, ..., 0, 7, 0],
#        [0, 0, 0, ..., 0, 0, 4]], dtype=int64)
